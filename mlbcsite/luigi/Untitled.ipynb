# %%
import pandas as pd

# %%
r = pd.read_json("./scraped/0.json",lines=True)

# %%
r
# Out:
#                              company  \
# 0                           Invicro
# 1                      Starry, Inc.
# 2                              TiVo
# 3   Pixels 360 - WWW.PIXELS-360.COM
# 4           Embark Veterinary, Inc.
# 5                      Digital Loom
#
#                                             job_desc  \
# 0   Invicro          3 reviews  Boston, MA 02210 ...
# 1   Starry, Inc.  Boston, MA 02111   Who You Are:...
# 2   TiVo          54 reviews  Boston, MA    Hi. W...
# 3   Pixels 360 - WWW.PIXELS-360.COM  Rockland, MA...
# 4   Embark Veterinary, Inc.  Boston, MA    Embark...
# 5   Digital Loom  Cambridge, MA    Job Summary   ...
#
#                                             job_page  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...
